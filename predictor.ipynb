# %%
pip install yfinance
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf

# %%
sp500 = yf.Ticker("^GSPC")

# %%
sp500 = sp500.history(period="max")

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2023-10-25 00:00:00-04:00  4232.419922  4232.419922  4181.419922  4186.770020
# 2023-10-26 00:00:00-04:00  4175.990234  4183.600098  4127.899902  4137.229980
# 2023-10-27 00:00:00-04:00  4152.930176  4156.700195  4103.779785  4117.370117
# 2023-10-30 00:00:00-04:00  4139.390137  4177.470215  4132.939941  4166.819824
# 2023-10-31 00:00:00-04:00  4171.330078  4195.549805  4153.120117  4193.799805
#
# ...

# %%
sp500.index
# Out:
# DatetimeIndex(['1927-12-30 00:00:00-05:00', '1928-01-03 00:00:00-05:00',
#                '1928-01-04 00:00:00-05:00', '1928-01-05 00:00:00-05:00',
#                '1928-01-06 00:00:00-05:00', '1928-01-09 00:00:00-05:00',
#                '1928-01-10 00:00:00-05:00', '1928-01-11 00:00:00-05:00',
#                '1928-01-12 00:00:00-05:00', '1928-01-13 00:00:00-05:00',
#                ...
#                '2023-10-18 00:00:00-04:00', '2023-10-19 00:00:00-04:00',
#                '2023-10-20 00:00:00-04:00', '2023-10-23 00:00:00-04:00',
#                '2023-10-24 00:00:00-04:00', '2023-10-25 00:00:00-04:00',
#                '2023-10-26 00:00:00-04:00', '2023-10-27 00:00:00-04:00',
#                '2023-10-30 00:00:00-04:00', '2023-10-31 00:00:00-04:00'],
#               dtype='datetime64[ns, America/New_York]', name='Date', length=24074, freq=None)

# %%
sp500.plot.line(y="Close", use_index=True)
# Out:
# <Axes: xlabel='Date'>

# %%
del sp500["Dividends"]
del sp500["Stock Splits"]

# %%
sp500["Tomorrow"] = sp500["Close"].shift(-1)

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2023-10-25 00:00:00-04:00  4232.419922  4232.419922  4181.419922  4186.770020
# 2023-10-26 00:00:00-04:00  4175.990234  4183.600098  4127.899902  4137.229980
# 2023-10-27 00:00:00-04:00  4152.930176  4156.700195  4103.779785  4117.370117
# 2023-10-30 00:00:00-04:00  4139.390137  4177.470215  4132.939941  4166.819824
# 2023-10-31 00:00:00-04:00  4171.330078  4195.549805  4153.120117  4193.799805
#
# ...

# %%
sp500["Target"] = (sp500["Tomorrow"] > sp500["Close"]).astype(int)

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2023-10-25 00:00:00-04:00  4232.419922  4232.419922  4181.419922  4186.770020
# 2023-10-26 00:00:00-04:00  4175.990234  4183.600098  4127.899902  4137.229980
# 2023-10-27 00:00:00-04:00  4152.930176  4156.700195  4103.779785  4117.370117
# 2023-10-30 00:00:00-04:00  4139.390137  4177.470215  4132.939941  4166.819824
# 2023-10-31 00:00:00-04:00  4171.330078  4195.549805  4153.120117  4193.799805
#
# ...

# %%
sp500 = sp500.loc["1990-01-01":].copy()

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1990-01-02 00:00:00-05:00   353.399994   359.690002   351.980011   359.690002
# 1990-01-03 00:00:00-05:00   359.690002   360.589996   357.890015   358.760010
# 1990-01-04 00:00:00-05:00   358.760010   358.760010   352.890015   355.670013
# 1990-01-05 00:00:00-05:00   355.670013   355.670013   351.350006   352.200012
# 1990-01-08 00:00:00-05:00   352.200012   354.239990   350.540009   353.790009
# ...                                ...          ...          ...          ...
# 2023-10-25 00:00:00-04:00  4232.419922  4232.419922  4181.419922  4186.770020
# 2023-10-26 00:00:00-04:00  4175.990234  4183.600098  4127.899902  4137.229980
# 2023-10-27 00:00:00-04:00  4152.930176  4156.700195  4103.779785  4117.370117
# 2023-10-30 00:00:00-04:00  4139.390137  4177.470215  4132.939941  4166.819824
# 2023-10-31 00:00:00-04:00  4171.330078  4195.549805  4153.120117  4193.799805
#
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators=100, min_samples_split=100, random_state=1)

train = sp500.iloc[:-100]
test = sp500.iloc[-100:]

predictors = ["Close", "Volume", "Open", "High", "Low"]
model.fit(train[predictors], train["Target"])
# Out:
# RandomForestClassifier(min_samples_split=100, random_state=1)

# %%
from sklearn.metrics import precision_score

preds = model.predict(test[predictors])

# %%
import pandas as pd
preds = pd.Series(preds, index=test.index)

# %%
preds
# Out:
# Date
# 2023-06-09 00:00:00-04:00    1
# 2023-06-12 00:00:00-04:00    1
# 2023-06-13 00:00:00-04:00    1
# 2023-06-14 00:00:00-04:00    1
# 2023-06-15 00:00:00-04:00    1
#                             ..
# 2023-10-25 00:00:00-04:00    1
# 2023-10-26 00:00:00-04:00    0
# 2023-10-27 00:00:00-04:00    0
# 2023-10-30 00:00:00-04:00    0
# 2023-10-31 00:00:00-04:00    0
# Length: 100, dtype: int32

# %%
precision_score(test["Target"], preds)
# Out:
# 0.4788732394366197

# %%
combined = pd.concat([test["Target"], preds], axis=1)

# %%
combined.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
def predict(train, test, predictors, model):
    model.fit(train[predictors], train["Target"])
    preds = model.predict(test[predictors])
    preds = pd.Series(preds, index=test.index, name="Predictions")
    combined = pd.concat([test["Target"], preds], axis=1)
    return combined

# %%
def backtest(data, model, predictors, start=2500, step=250):
    all_predictions = []

    for i in range(start, data.shape[0], step):
        train = data.iloc[0:i].copy()
        test = data.iloc[i:(i+step)].copy()
        predictions = predict(train, test, predictors, model)
        all_predictions.append(predictions)
    return pd.concat(all_predictions)

# %%
predictions = backtest(sp500, model, predictors)

# %%
predictions["Predictions"].value_counts()
# Out:
# Predictions
# 0    3444
# 1    2580
# Name: count, dtype: int64

# %%
precision_score(predictions["Target"], predictions["Predictions"])
# Out:
# 0.5275193798449612

# %%
predictions["Target"].value_counts() / predictions.shape[0]
# Out:
# Target
# 1    0.533201
# 0    0.466799
# Name: count, dtype: float64

# %%
horizons = [2,5,60,250,1000]
new_predictors = []

for horizon in horizons:
    rolling_averages = sp500.rolling(horizon).mean()

    ratio_column = f"Close_Ratio_{horizon}"
    sp500[ratio_column] = sp500["Close"] / rolling_averages["Close"]

    trend_column = f"Trend_{horizon}"
    sp500[trend_column] = sp500.shift(1).rolling(horizon).sum()["Target"]

    new_predictors += [ratio_column, trend_column]

# %%
sp500 = sp500.dropna()

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1993-12-14 00:00:00-05:00   465.730011   466.119995   462.459991   463.059998
# 1993-12-15 00:00:00-05:00   463.059998   463.690002   461.839996   461.839996
# 1993-12-16 00:00:00-05:00   461.859985   463.980011   461.859985   463.339996
# 1993-12-17 00:00:00-05:00   463.339996   466.380005   463.339996   466.380005
# 1993-12-20 00:00:00-05:00   466.380005   466.899994   465.529999   465.850006
# ...                                ...          ...          ...          ...
# 2023-10-24 00:00:00-04:00  4235.790039  4259.379883  4219.430176  4247.680176
# 2023-10-25 00:00:00-04:00  4232.419922  4232.419922  4181.419922  4186.770020
# 2023-10-26 00:00:00-04:00  4175.990234  4183.600098  4127.899902  4137.229980
# 2023-10-27 00:00:00-04:00  4152.930176  4156.700195  4103.779785  4117.370117
# 2023-10-30 00:00:00-04:00  4139.390137  4177.470215  4132.939941  4166.819824
#
# ...

# %%
model = RandomForestClassifier(n_estimators=250, min_samples_split=40, random_state=1)

# %%
def predict(train, test, predictors, model):
    model.fit(train[predictors], train["Target"])
    preds = model.predict_proba(test[predictors]) [:,1]
    preds[preds >= .6] = 1
    preds[preds < .6] = 0
    preds = pd.Series(preds, index=test.index, name="Predictions")
    combined = pd.concat([test["Target"], preds], axis=1)
    return combined

# %%
predictions = backtest(sp500, model, new_predictors)

# %%
predictions["Predictions"].value_counts()
# Out:
# Predictions
# 0.0    4157
# 1.0     866
# Name: count, dtype: int64

# %%
precision_score(predictions["Target"], predictions["Predictions"])
# Out:
# 0.558891454965358

# %%
sp500_copy = sp500.copy()
sp500_copy['Day_Pct_Change'] = sp500_copy['Close'].pct_change() * 100

# %%
sp500_copy = sp500.copy()
sp500_copy['MA_5'] = sp500_copy['Close'].rolling(window=5).mean()
sp500_copy['MA_30'] = sp500_copy['Close'].rolling(window=30).mean()

# %%
sp500_copy = sp500.copy()
delta = sp500_copy['Close'].diff()
gain = (delta.where(delta > 0, 0)).rolling(window=14).mean()
loss = (-delta.where(delta < 0, 0)).rolling(window=14).mean()

rs = gain / loss
sp500_copy.loc[:, 'RSI'] = 100 - (100 / (1 + rs))

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1993-12-14 00:00:00-05:00   465.730011   466.119995   462.459991   463.059998
# 1993-12-15 00:00:00-05:00   463.059998   463.690002   461.839996   461.839996
# 1993-12-16 00:00:00-05:00   461.859985   463.980011   461.859985   463.339996
# 1993-12-17 00:00:00-05:00   463.339996   466.380005   463.339996   466.380005
# 1993-12-20 00:00:00-05:00   466.380005   466.899994   465.529999   465.850006
# ...                                ...          ...          ...          ...
# 2023-10-24 00:00:00-04:00  4235.790039  4259.379883  4219.430176  4247.680176
# 2023-10-25 00:00:00-04:00  4232.419922  4232.419922  4181.419922  4186.770020
# 2023-10-26 00:00:00-04:00  4175.990234  4183.600098  4127.899902  4137.229980
# 2023-10-27 00:00:00-04:00  4152.930176  4156.700195  4103.779785  4117.370117
# 2023-10-30 00:00:00-04:00  4139.390137  4177.470215  4132.939941  4166.819824
#
# ...

# %%
sp500 = sp500.dropna()

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1993-12-14 00:00:00-05:00   465.730011   466.119995   462.459991   463.059998
# 1993-12-15 00:00:00-05:00   463.059998   463.690002   461.839996   461.839996
# 1993-12-16 00:00:00-05:00   461.859985   463.980011   461.859985   463.339996
# 1993-12-17 00:00:00-05:00   463.339996   466.380005   463.339996   466.380005
# 1993-12-20 00:00:00-05:00   466.380005   466.899994   465.529999   465.850006
# ...                                ...          ...          ...          ...
# 2023-10-24 00:00:00-04:00  4235.790039  4259.379883  4219.430176  4247.680176
# 2023-10-25 00:00:00-04:00  4232.419922  4232.419922  4181.419922  4186.770020
# 2023-10-26 00:00:00-04:00  4175.990234  4183.600098  4127.899902  4137.229980
# 2023-10-27 00:00:00-04:00  4152.930176  4156.700195  4103.779785  4117.370117
# 2023-10-30 00:00:00-04:00  4139.390137  4177.470215  4132.939941  4166.819824
#
# ...

# %%
stocks = ['AAPL', 'MSFT', 'NVDA', 'GOOGL', 'AMZN']
stock_data = {}

for stock in stocks:
    stock_data[stock] = yf.Ticker(stock).history(period="max")

# %%
for stock, data in stock_data.items():
    data[f'{stock}_Close'] = data['Close']
    data[f'{stock}_Volume'] = data['Volume']
    data[f'{stock}_Day_Pct_Change'] = data['Close'].pct_change() * 100
    data[f'{stock}_MA_5'] = data['Close'].rolling(window=5).mean()
    data[f'{stock}_MA_30'] = data['Close'].rolling(window=30).mean()

    delta = data['Close'].diff()
    gain = (delta.where(delta > 0, 0)).rolling(window=14).mean()
    loss = (-delta.where(delta < 0, 0)).rolling(window=14).mean()
    rs = gain / loss
    data[f'{stock}_RSI'] = 100 - (100 / (1 + rs))

# %%
for stock, data in stock_data.items():
    relevant_columns = [f'{stock}_Close', f'{stock}_Volume', f'{stock}_Day_Pct_Change', f'{stock}_MA_5', f'{stock}_MA_30', f'{stock}_RSI']
    sp500 = sp500.merge(data[relevant_columns], left_index=True, right_index=True, how='left')

# %%
extended_predictors = new_predictors.copy()

for stock in stocks:
    extended_predictors.extend([
        f'{stock}_Close',
        f'{stock}_Volume',
        f'{stock}_Day_Pct_Change',
        f'{stock}_MA_5',
        f'{stock}_MA_30',
        f'{stock}_RSI'
    ])

# %%
print(sp500.isnull().sum())
# Out:
# Open                       0
# High                       0
# Low                        0
# Close                      0
# Volume                     0
# Tomorrow                   0
# Target                     0
# Close_Ratio_2              0
# Trend_2                    0
# Close_Ratio_5              0
# Trend_5                    0
# Close_Ratio_60             0
# Trend_60                   0
# Close_Ratio_250            0
# Trend_250                  0
# Close_Ratio_1000           0
# Trend_1000                 0
# AAPL_Close                 0
# AAPL_Volume                0
# AAPL_Day_Pct_Change        0
# AAPL_MA_5                  0
# AAPL_MA_30                 0
# AAPL_RSI                   0
# MSFT_Close                 0
# MSFT_Volume                0
# MSFT_Day_Pct_Change        0
# MSFT_MA_5                  0
# MSFT_MA_30                 0
# MSFT_RSI                   0
# NVDA_Close              1289
# NVDA_Volume             1289
# NVDA_Day_Pct_Change     1290
# ...

# %%
threshold = len(sp500) * 0.5
sp500.dropna(thresh=threshold, axis=1, inplace=True)

# %%
sp500.ffill(inplace=True)
sp500.bfill(inplace=True)

# %%
predictions = backtest(sp500, model, extended_predictors)

# %%
predictions["Predictions"].value_counts()
# Out:
# Predictions
# 0.0    4785
# 1.0     238
# Name: count, dtype: int64

# %%
precision_score(predictions["Target"], predictions["Predictions"])
# Out:
# 0.5966386554621849
